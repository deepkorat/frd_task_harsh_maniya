# %%
import pandas as pd

# %%
print("******* welcome Riders! *******")

# Sample bike sales data getting from AI generates
bike_sales_data  = [
    {"Brand": "Honda", "Model": "CB 1000R", "Year": 2020, "Color": "Matte Black", "Price": 12999},
    {"Brand": "Yamaha", "Model": "YZF-R1", "Year": 2019, "Color": "Racing Blue", "Price": 17599},
    {"Brand": "Suzuki", "Model": "GSX-R750", "Year": 2021, "Color": "Metallic Triton Blue", "Price": 11299},
    {"Brand": "Kawasaki", "Model": "Ninja ZX-10R", "Year": 2022, "Color": "Lime Green", "Price": 16399},
    {"Brand": "Ducati", "Model": "Panigale V4", "Year": 2022, "Color": "Ducati Red", "Price": 24095},
    {"Brand": "BMW", "Model": "S 1000 RR", "Year": 2023, "Color": "Light White", "Price": 16995},
    {"Brand": "Harley-Davidson", "Model": "Street Glide", "Year": 2023, "Color": "Vivid Black", "Price": 21999},
    {"Brand": "Royal Enfield", "Model": "Street Triple RS", "Year": 2019, "Color": "Sapphire Black", "Price": 12550},
    {"Brand": "KTM", "Model": "1290 Super Duke R", "Year": 2020, "Color": "Black", "Price": 18699},
    {"Brand": "Hero", "Model": "Tuono V4 Factory", "Year": 2020, "Color": "Atomico 6", "Price": 17999},
    {"Brand": "Royal Enfield", "Model": "Scout Bobber Sixty", "Year": 2022, "Color": "Thunder Black", "Price": 8999},
    {"Brand": "Ola", "Model": "Brutale 1000 RR", "Year": 2023, "Color": "Pearl White / Matte Carbon",
     "Price": 31998},
    {"Brand": "ola", "Model": "Vitpilen 701", "Year": 2023, "Color": "Silver", "Price": 11999},
    {"Brand": "Hero", "Model": "TNT 600i", "Year": 2019, "Color": "Red", "Price": 7499},
    {"Brand": "Royal Enfield", "Model": "Interceptor 650", "Year": 2021, "Color": "Sunset Strip", "Price": 5799},
    {"Brand": "Honda", "Model": "V7 Stone", "Year": 2020, "Color": "Nero Ruvido", "Price": 9390},
    {"Brand": "Hero", "Model": "SR/F", "Year": 2020, "Color": "Cypher Black", "Price": 20995},
    {"Brand": "Suzuki", "Model": "Commando 961 Cafe Racer", "Year": 2021, "Color": "British Racing Green",
     "Price": 21995},
    {"Brand": "Hero", "Model": "FX", "Year": 2021, "Color": "Dune", "Price": 9295},
    {"Brand": "KTM", "Model": "Eva Ribelle", "Year": 2019, "Color": "Electric Blue", "Price": 24470}
]
# Out:
# ******* welcome Riders! *******

# %%
bike_df = pd.DataFrame.from_dict(bike_sales_data)

# %%
bike_df
# Out:
#               Brand                    Model  Year  \
# 0             Honda                 CB 1000R  2020
# 1            Yamaha                   YZF-R1  2019
# 2            Suzuki                 GSX-R750  2021
# 3          Kawasaki             Ninja ZX-10R  2022
# 4            Ducati              Panigale V4  2022
# 5               BMW                S 1000 RR  2023
# 6   Harley-Davidson             Street Glide  2023
# 7     Royal Enfield         Street Triple RS  2019
# 8               KTM        1290 Super Duke R  2020
# 9              Hero         Tuono V4 Factory  2020
# 10    Royal Enfield       Scout Bobber Sixty  2022
# 11              Ola          Brutale 1000 RR  2023
# 12              ola             Vitpilen 701  2023
# 13             Hero                 TNT 600i  2019
# 14    Royal Enfield          Interceptor 650  2021
# 15            Honda                 V7 Stone  2020
# 16             Hero                     SR/F  2020
# ...

# %%
filter_brand = bike_df[bike_df["Brand"] == "Honda"]
print(filter_brand)
# Out:
#     Brand     Model  Year        Color  Price
# 0   Honda  CB 1000R  2020  Matte Black  12999
# 15  Honda  V7 Stone  2020  Nero Ruvido   9390

# %%
def show_all_brands():
    print(bike_df.columns)
def show_particular_brand(brand):
    filter_brand = bike_df[bike_df["Brand"] == "Honda"]
    print(filter_brand)

# %%
show_all_brands()
# Out:
# Index(['Brand', 'Model', 'Year', 'Color', 'Price'], dtype='object')

# %%
bike

# %%
# Greetings massage

Customer_name = input("What's the name of buyer ?: ")
print("Hellow, " + Customer_name + "!")


# display all data--------1
def display_bike_sales(records):
    for i, record in enumerate(records):
        print(f"Record {i + 1}:")
        print(f"Brand: {record['Brand']}")
        print(f"Model: {record['Model']}")
        print(f"Year: {record['Year']}")
        print(f"Color: {record['Color']}")
        print(f"Price: ${record['Price']:.2f}")
        print()


# Budjet of customer---------2
def Budget(records, min_price, max_price):
    data = (min_price, max_price)
    result = [record for record in records if min_price <= record['Price'] <= max_price]
    print(f"Bikes within the price range of ${min_price:.2f} to ${max_price:.2f}:")
    if result:
        for i, record in enumerate(result):
            print(f"Record {i + 1}:")
            print(f"Brand: {record['Brand']}")
            print(f"Model: {record['Model']}")
            print(f"Year: {record['Year']}")
            print(f"Color: {record['Color']}")
            print(f"Price: ${record['Price']:.2f}")
            print()
    else:
        print("No bikes found within the specified price range.")
    print()


 # Menufacturing year------------3
def year_of_menufacturing(records):
    data = int(input("Enter the year of manufacture: "))
    result = [record for record in records if record['Year'] == data]
    if result:
        print(f"Bikes manufactured in {data}:")
        for i, record in enumerate(result):
            print(f"Record {i + 1}:")
            print(f"Brand: {record['Brand']}")
            print(f"Model: {record['Model']}")
            print(f"Year: {record['Year']}")
            print(f"Color: {record['Color']}")
            print(f"Price: ${record['Price']:.2f}")
            print()
    else:
        print(f"No bikes found for the year {data}.")

# Available Brand for user search

def bikes_brand(records):
    data = str(input("Enter the brand: "))
    match_brand = [record for record in records if record['Brand'].lower() == data.lower()]
    if match_brand:
        print(f"Bikes manufactured in {data}:")
        for i, record in enumerate(match_brand):
             print(f"Record {i + 1}:")
             print(f"Brand: {record['Brand']}")
             print(f"Model: {record['Model']}")
             print(f"Year: {record['Year']}")
             print(f"Color: {record['Color']}")
             print(f"Price: ${record['Price']:.2f}")
             print()
    else:
        print(f"No found of this brand which you entered {data}.")



# Choice of customer
if _name_ == "_main_":
    while True:
        print("Enter your choice..:")
        print("1. Display all bike which is availble. ")
        print("2. Find bikes within your budget($7499-$42470")
        print("3. Sort a menufacturing year(2019 to 2023)")
        print("4. Find bikes by brand")
        print("                                  ** Available Brand **")
        print("** Honda, Yamaha, Suzuki, Kawasaki, Ducati, BMW, Harley-Davidson,Royal Enfield, KTM, Hero, Ola **")
        print("5. Quit")

        choice = input("Enter your choice (1-5): ")

        if choice == '1':
            display_bike_sales(bike_sales_data)
        elif choice == '2':
            min_price = float(input("Enter minimum price: $"))
            max_price = float(input("Enter maximum price: $"))
            Budget(bike_sales_data, min_price, max_price)
        elif choice == '3':
            year_of_menufacturing(bike_sales_data)
        elif choice == '4':
            bikes_brand(bike_sales_data)
        elif choice == '5':
            print("Thank you!")
            break
        else:
            print("Invalid choice. Please select a valid option.")
